# %%
import gdown

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Gouthum\\Downloads\\waste detection\\EcoSort-Vision'

# %%
url = "https://drive.google.com/file/d/1orj3RpwtiAE4RfRW9hPSNaMSSuMZUpTm/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1orj3RpwtiAE4RfRW9hPSNaMSSuMZUpTm'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='

gdown.download(prefix+file_id, "data/waste-detection.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1orj3RpwtiAE4RfRW9hPSNaMSSuMZUpTm
# From (redirected): https://drive.google.com/uc?id=1orj3RpwtiAE4RfRW9hPSNaMSSuMZUpTm&confirm=t&uuid=615a1758-60fd-40e1-9e60-872eee17065f
# To: c:\Users\Gouthum\Downloads\waste detection\EcoSort-Vision\data\waste-detection.zip
# 100%|██████████| 295M/295M [01:47<00:00, 2.75MB/s]
# 'data/waste-detection.zip'

# %%
# %pwd
# Out:
# 'c:\\Users\\Gouthum\\Downloads\\waste detection\\EcoSort-Vision\\research'
